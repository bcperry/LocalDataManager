# %%
from Data_Management.file_manager import FileManager

# %%
manager = FileManager(base_path= 'data/managed', db_file='tinker.db')

# %%
# Reading a file 
f = open(r'test/testfile.txt', 'rb')
# f = open(r'test.jpg', 'rb')

# %%
manager.hash_file(f)
# Out:
# '3ac2be693b3995e74da80b48d3713f4578add9504d6de4f52db84ec51c2824b7'

# %%
manager.save_file(f, 'bronze')
# Out:
# True

# %%
import shutil
# shutil.rmtree('data')

# %%
manager.get_hashes()
# Out:
# ['3ac2be693b3995e74da80b48d3713f4578add9504d6de4f52db84ec51c2824b7',
#  '9f86d081884c7d659a2feaa0c55ad015a3bf4f1b2b0b822cd15d6c15b0f00a08']

# %%
manager.get_names()
# Out:
# ['testfile.txt', 'V002_testfile.txt']
